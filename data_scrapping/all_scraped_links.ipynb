airlinequality.com/airline-reviews/hainan-airlines','https://www.airlinequality.com/airline-reviews/hawaiian-airlines','https://www.airlinequality.com/airline-reviews/helvetic','https://www.airlinequality.com/airline-reviews/henan-airlines','https://www.airlinequality.com/airline-reviews/hi-fly','https://www.airlinequality.com/airline-reviews/himalaya-airlines','https://www.airlinequality.com/airline-reviews/hong-kong','https://www.airlinequality.com/airline-reviews/hong-kong-airlines','https://www.airlinequality.com/airline-reviews/hop','https://www.airlinequality.com/airline-reviews/iberia','https://www.airlinequality.com/airline-reviews/iberia-express','https://www.airlinequality.com/airline-reviews/icelandair','https://www.airlinequality.com/airline-reviews/indigo-airlines','https://www.airlinequality.com/airline-reviews/insel-air','https://www.airlinequality.com/airline-reviews/intercaribbean-airways','https://www.airlinequality.com/airline-reviews/interjet','https://www.airlinequality.com/airline-reviews/intersky','https://www.airlinequality.com/airline-reviews/iran-air','https://www.airlinequality.com/airline-reviews/iran-aseman','https://www.airlinequality.com/airline-reviews/iraqi-airways','https://www.airlinequality.com/airline-reviews/island','https://www.airlinequality.com/airline-reviews/israir-airlines','https://www.airlinequality.com/airline-reviews/ita-airways']

# %%
import requests
import pandas as pd

# %%
def get_attr_df(soup):
    reviews = soup1.find_all(class_="body")
    reviews_list = []
    for review in reviews:
        review_dict = {}
        table = review.find(class_="review-stats").find(class_="review-ratings")
        stars_dict = {}
        for row in table.find_all("tr"): 
            cells = row.find_all("td")

        
            stars = list(cells[1].find_all(class_='star fill'))
            if len(stars)>0:
                stars = len(stars)
        
        
            for i in list(cells[0]):
                stars_dict[i] = stars
                if type(stars_dict[i]) is int:
                    review_dict[i] = stars_dict[i]
                else:
                    for j in list(cells[1]):
                        review_dict[i] = j
            
            review_dict.update({"id": review["id"]})
        reviews_list.append(review_dict)
        reviews_df = pd.DataFrame(reviews_list).set_index('id')
    
    return reviews_df

# %%
def get_content_list(soup):
  content = soup.find_all(class_="text_content")
  content_list = [i.get_text() for i in content]
  # get the comment in the right format
  content_list = [i.replace("✅ Trip Verified |","") for i in content_list]
  content_list = [i.replace("Not Verified |","") for i in content_list]
  return content_list

# %%
def get_reviews():
  
    def get_content_list(soup):
        content = soup.find_all(class_="text_content")
        content_list = [i.get_text() for i in content]
        # get the comment in the right format
        content_list = [i.replace("✅ Trip Verified |","") for i in content_list]
        content_list = [i.replace("Not Verified |","") for i in content_list]
        return content_list
    
    def get_attr_df(soup):
        reviews = soup1.find_all(class_="body")
        reviews_list = []
        for review in reviews:
            review_dict = {}
            table = review.find(class_="review-stats").find(class_="review-ratings")
            stars_dict = {}
            for row in table.find_all("tr"): 
                cells = row.find_all("td")
        
                stars = list(cells[1].find_all(class_='star fill'))
                if len(stars)>0:
                    stars = len(stars)       
        
                for i in list(cells[0]):
                    stars_dict[i] = stars
                    if type(stars_dict[i]) is int:
                        review_dict[i] = stars_dict[i]
                    else:
                        for j in list(cells[1]):
                            review_dict[i] = j
            
                review_dict.update({"id": review["id"]})
            reviews_list.append(review_dict)
            reviews_df = pd.DataFrame(reviews_list).set_index('id')
        return reviews_df
    
    df = get_attr_df(soup)
    df['content']=get_content_list(soup)
    return df

# %%
all_links[1].split("/")[-1]
# Out:
# 'adria-airways'

# %% [markdown]
# Extract from the first page (this part is only to visualize outputs)

# %%
# looking at the first page of easyjet
for each_link in all_links:
    try:
    #     easyjetpage1=requests.get("https://www.airlinequality.com/airline-reviews/easyjet")
        easyjetpage1=requests.get(each_link)
        # easyjetpage1

        from bs4 import BeautifulSoup
        soup1 = BeautifulSoup(easyjetpage1.content, 'html.parser')
        # print(soup1.prettify())

        reviews = soup1.find_all(class_="body")
        reviews_list = []
        for review in reviews:
            review_dict = {}
            table = review.find(class_="review-stats").find(class_="review-ratings")
            stars_dict = {}
            for row in table.find_all("tr"): 
                cells = row.find_all("td")


                #for i in list(cells[0].text): 
                stars = list(cells[1].find_all(class_='star fill'))
                if len(stars)>0:
                    stars = len(stars)


                for i in list(cells[0]):
                    stars_dict[i] = stars
                    if type(stars_dict[i]) is int:
                        review_dict[i] = stars_dict[i]
                    else:
                        for j in list(cells[1]):
                            review_dict[i] = j


    #         print(review_dict)

        df = get_attr_df(soup1)
        df['content']=get_content_list(soup1)
        # df
        review_list = []
        for page in range(0,126):
            easyjetpage = requests.get(each_link+"/page/{}/".format(page))
            soup = BeautifulSoup(easyjetpage.content, 'html.parser')
            df = get_reviews()
            review_list.append(df)

        df_easyjet = pd.concat(review_list, axis=0, sort=True)
        df_easyjet.shape
        df_easyjet.to_csv(each_link.split("/")[-1]+'.csv')
        print("Done... ", each_link)
    except:
        print("Moving on from.... ", each_link)
        if(review_list != []):
            df_easyjet = pd.concat(review_list, axis=0, sort=True)
            df_easyjet.shape
            df_easyjet.to_csv(each_link.split("/")[-1]+'.csv')
            print("Done... ", each_link)
# Out:
# Moving on from....  https://www.airlinequality.com/airline-reviews/pacific-airlines
# Done...  https://www.airlinequality.com/airline-reviews/pacific-airlines
# Moving on from....  https://www.airlinequality.com/airline-reviews/pia-pakistan-international-airlines
# Done...  https://www.airlinequality.com/airline-reviews/pia-pakistan-international-airlines
# Moving on from....  https://www.airlinequality.com/airline-reviews/pal-express
# Done...  https://www.airlinequality.com/airline-reviews/pal-express
# Moving on from....  https://www.airlinequality.com/airline-reviews/pan-pacific-airlines
# Done...  https://www.airlinequality.com/airline-reviews/pan-pacific-airlines
# Moving on from....  https://www.airlinequality.com/airline-reviews/passaredo-linhas-aereas
# Done...  https://www.airlinequality.com/airline-reviews/passaredo-linhas-aereas
# Moving on from....  https://www.airlinequality.com/airline-reviews/pawa-dominicana
# ...

# %% [markdown]
# This can be generalized to all the comments of Easyjet (run this part to get a dataframe of all comments of easyjet)

# %% [markdown]
# Scrap other low-cost airlines
